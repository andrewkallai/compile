# %%
# %matplotlib inline
from fitting_and_plotting import plot_instruction_counts_v_textseg, plot_instruction_counts_histograms
from read_column import outlier_rows
import csv
from IPython.display import HTML, display
import pandas   

langs = pandas.read_csv('../dataset_download/indices.csv')["language"]
CSV_STORAGE="/home/3302/hf_py_code/compile/csv_data/inst_scatterplots"

# %%
for i in langs:
    plot_instruction_counts_histograms(i, CSV_STORAGE, show=True)
# Out:
# 31525
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/shared/anaconda/5.3.1-python3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'instruction'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-cc4c7f270a64> in <module>()
#       1 for i in langs:
# ----> 2     plot_instruction_counts_histograms(i, CSV_STORAGE, show=True)
#
# ~/hf_py_code/compile/compile_time_analysis_tools/python_processing/fitting_and_plotting.py in plot_instruction_counts_histograms(lang, storage, show)
#      47 def plot_instruction_counts_histograms(lang: str, storage: str, show: bool = False) -> None:
#      48     df = csv_to_pandas_df(lang, storage)
# ---> 49     inst_data = df["instruction"]
#      50     plt.hist(inst_data, bins='auto', alpha=1, color='b')
#      51     plt.title("Histogram of Compiler Instructions ("+lang+")")
#
# /opt/shared/anaconda/5.3.1-python3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /opt/shared/anaconda/5.3.1-python3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /opt/shared/anaconda/5.3.1-python3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /opt/shared/anaconda/5.3.1-python3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /opt/shared/anaconda/5.3.1-python3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'instruction'

# %%
for i in langs:
    plot_instruction_counts_v_textseg(i, CSV_STORAGE, show=True)

# %%
for i in langs:
    display(HTML(outlier_rows(i, CSV_STORAGE).to_html(index=False)))
